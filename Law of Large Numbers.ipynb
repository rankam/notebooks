# %%
# %pylab inline
import numpy as np
import pandas as pd
import pymc as pm
plt.style.use('fivethirtyeight')

# %%
figsize(12.5,6)
sample_size = 100000
expected_value = lambda_ = 4.5
poi = pm.rpoisson
N_samples = range(1, sample_size, 100)

for k in range(3):
    samples = poi(lambda_, size=sample_size)
    partial_average = [samples[:i].mean() for i in N_samples]
    plt.plot(N_samples, partial_average, lw=1.5, label='average of $n$ samples; seq. %d' %k)

plt.plot(N_samples, expected_value * np.ones_like(partial_average),
     ls='--', label='true expected value', c='k')

plt.ylim(4.35, 4.65)
plt.title('Convergence of the average of \n random variables to its expected value')
plt.ylabel('average of $n$ samples')
plt.xlabel('# of samples, $n$')
plt.legend();
plt.subplots_adjust(bottom=0.15)

# %%
N_Y = 250
N_array = np.arange(1000, 50000, 2500)
D_N_results = np.zeros(len(N_array))
lambda_ = 4.5
expected_value = lambda_

def D_N(n):
    '''
    Approximates D_n, the average variance of using n samples
    '''
    Z = poi(lambda_, size = (n,N_Y))
    average_Z = Z.mean(axis=0)
    return np.sqrt(((average_Z - expected_value) **2).mean())

for i,n in enumerate(N_array):
    D_N_results[i] = D_N(n)
    
plt.xlabel("$N$")
plt.ylabel('expected squared-distance from true value')
plt.plot(N_array, D_N_results, lw=3, label='exptected distance between\n\expected value and \naverage of $N$ randomv variables.')
plt.plot(N_array, np.sqrt(expected_value) / np.sqrt(N_array), lw=2, ls='--',label=r"$\frac{\sqrt{\lambda}}{\sqrt{N}}$")
plt.legend()
plt.title("How 'fast' is the sample average converging?")
plt.subplots_adjust(bottom=0.15)

# %%
mj = pd.read_csv('/users/aaronrank/dropbox/mj_game_stats.csv')
mj.columns = [col.lower() for col in mj.columns]

# %%
mj.head()
# Out:
#    mjg  tmg        date             opponent result  mj_score  opponent_score  \
# 0  108    1  1986-11-01      New York Knicks      W       108             103
# 1  109    2  1986-11-02  Cleveland Cavaliers      W        94              89
# 2  110    3  1986-11-04    San Antonio Spurs      W       111             104
# 3  111    4  1986-11-07      Detroit Pistons      L       109             115
# 4  112    5  1986-11-08         Phoenix Suns      W       101              96
#
#    mp  fg  fga ...   fta  orb  drb  trb  ast  stl  blk  to  pf  pts
# 0  41  15   31 ...    22    2    4    6    3    4    3   6   2   50
# 1  39  16   31 ...    12    6    2    8    2    0    4   3   3   41
# 2  44  14   31 ...    13    3    5    8    5    4    2   6   2   34
# 3  42  11   26 ...    15    0    0    0    5    1    1   3   4   33
# 4  39  17   27 ...     5    3    3    6    3    5    0   3   2   39
#
# [5 rows x 23 columns]

# %%
N = len(mj['pts'])    
Y = mj['mj_score']
X = mj['pts']

ls_coef_ = np.cov(X,Y)[0,1] / np.var(X)
ls_intercept = Y.mean() - ls_coef_ * X.mean()

plt.scatter(X, Y, c='k')
plt.xlabel('MJ Points Scored')
plt.ylabel("MJ's Team Score")
plt.plot(X, ls_coef_ * X + ls_intercept, label='Least-sqares line')
plt.xlim(X.min(), X.max())
plt.ylim(Y.min(), Y.max())
plt.legend(loc='upper left')
plt.subplots_adjust(bottom=0.15)

# %%
import pymc as pm
from pymc.Matplot import plot as mcplot

std = pm.Uniform('std', 0, 100, trace=False)

@pm.deterministic
def prec(U=std):
    return 1./ (U) ** 2

beta = pm.Normal('beta', 0,0.0001)
alpha = pm.Normal('alpha', 0,0.0001)

@pm.deterministic
def mean(X=X, alpha=alpha, beta=beta):
    return alpha + beta * X

obs = pm.Normal('obs', mean, prec, value=Y, observed=True)
mcmc = pm.MCMC([obs, beta, alpha, std, prec])

mcmc.sample(100000, 80000)
mcplot(mcmc)
# Out:
#  [                  0%                  ] 806 of 100000 complete in 0.5 sec
#  [                  1%                  ] 1520 of 100000 complete in 1.0 sec
#  [                  2%                  ] 2276 of 100000 complete in 1.5 sec
#  [-                 2%                  ] 2992 of 100000 complete in 2.0 sec
#  [-                 3%                  ] 3680 of 100000 complete in 2.5 sec
#  [-                 4%                  ] 4374 of 100000 complete in 3.0 sec
#  [-                 5%                  ] 5070 of 100000 complete in 3.5 sec
#  [--                5%                  ] 5768 of 100000 complete in 4.0 sec
#  [--                6%                  ] 6412 of 100000 complete in 4.5 sec
#  [--                7%                  ] 7091 of 100000 complete in 5.0 sec
#  [--                7%                  ] 7775 of 100000 complete in 5.5 sec
#  [---               8%                  ] 8481 of 100000 complete in 6.0 sec
#  [---               9%                  ] 9174 of 100000 complete in 6.5 sec
#  [---               9%                  ] 9887 of 100000 complete in 7.0 sec
#  [----             10%                  ] 10599 of 100000 complete in 7.5 sec
#  [----             11%                  ] 11282 of 100000 complete in 8.0 sec
#  [----             11%                  ] 11961 of 100000 complete in 8.5 sec
#  [----             12%                  ] 12680 of 100000 complete in 9.0 sec
#  [-----            13%                  ] 13399 of 100000 complete in 9.5 sec
#  [-----            14%                  ] 14104 of 100000 complete in 10.0 sec
#  [-----            14%                  ] 14807 of 100000 complete in 10.5 sec
#  [-----            15%                  ] 15515 of 100000 complete in 11.0 sec
#  [------           16%                  ] 16114 of 100000 complete in 11.5 sec
#  [------           16%                  ] 16845 of 100000 complete in 12.0 sec
#  [------           17%                  ] 17557 of 100000 complete in 12.5 sec
#  [------           18%                  ] 18265 of 100000 complete in 13.0 sec
#  [-------          19%                  ] 19005 of 100000 complete in 13.5 sec
#  [-------          19%                  ] 19710 of 100000 complete in 14.0 sec
#  [-------          20%                  ] 20404 of 100000 complete in 14.5 sec
#  [--------         21%                  ] 21143 of 100000 complete in 15.0 sec
#  [--------         21%                  ] 21869 of 100000 complete in 15.5 sec
#  [--------         22%                  ] 22576 of 100000 complete in 16.0 sec
#  [--------         23%                  ] 23281 of 100000 complete in 16.5 sec
#  [---------        23%                  ] 23999 of 100000 complete in 17.0 sec
#  [---------        24%                  ] 24717 of 100000 complete in 17.5 sec
#  [---------        25%                  ] 25428 of 100000 complete in 18.0 sec
#  [-----------------55%                  ] 55255 of 100000 complete in 41.0 sec
#  [-----------------56%-                 ] 56008 of 100000 complete in 41.5 sec
#  [-----------------56%-                 ] 56728 of 100000 complete in 42.0 sec
#  [-----------------57%-                 ] 57459 of 100000 complete in 42.5 sec
#  [-----------------58%--                ] 58162 of 100000 complete in 43.0 sec
#  [-----------------58%--                ] 58899 of 100000 complete in 43.5 sec
#  [-----------------59%--                ] 59640 of 100000 complete in 44.0 sec
#  [-----------------60%--                ] 60386 of 100000 complete in 44.5 sec
#  [-----------------61%---               ] 61112 of 100000 complete in 45.0 sec
#  [-----------------61%---               ] 61849 of 100000 complete in 45.5 sec
#  [-----------------62%---               ] 62600 of 100000 complete in 46.0 sec
#  [-----------------63%----              ] 63316 of 100000 complete in 46.5 sec
#  [-----------------64%----              ] 64066 of 100000 complete in 47.0 sec
#  [-----------------64%----              ] 64813 of 100000 complete in 47.5 sec
#  [-----------------65%----              ] 65545 of 100000 complete in 48.0 sec
#  [-----------------66%-----             ] 66267 of 100000 complete in 48.5 sec
#  [-----------------67%-----             ] 67010 of 100000 complete in 49.0 sec
#  [-----------------67%-----             ] 67752 of 100000 complete in 49.5 sec
#  [-----------------68%------            ] 68485 of 100000 complete in 50.0 sec
#  [-----------------69%------            ] 69208 of 100000 complete in 50.5 sec
#  [-----------------69%------            ] 69934 of 100000 complete in 51.0 sec
#  [-----------------70%------            ] 70678 of 100000 complete in 51.5 sec
#  [-----------------71%-------           ] 71414 of 100000 complete in 52.0 sec
#  [-----------------72%-------           ] 72130 of 100000 complete in 52.5 sec
#  [-----------------72%-------           ] 72845 of 100000 complete in 53.0 sec
#  [-----------------73%-------           ] 73585 of 100000 complete in 53.5 sec
#  [-----------------74%--------          ] 74263 of 100000 complete in 54.0 sec
#  [-----------------74%--------          ] 74920 of 100000 complete in 54.5 sec
#  [-----------------75%--------          ] 75564 of 100000 complete in 55.0 sec
#  [-----------------76%--------          ] 76089 of 100000 complete in 55.5 sec
#  [-----------------76%---------         ] 76598 of 100000 complete in 56.0 sec
#  [-----------------77%---------         ] 77028 of 100000 complete in 56.5 sec
#  [-----------------77%---------         ] 77540 of 100000 complete in 57.0 sec
#  [-----------------78%---------         ] 78107 of 100000 complete in 57.5 sec
#  [-----------------78%---------         ] 78801 of 100000 complete in 58.0 sec
#  [-----------------79%----------        ] 79459 of 100000 complete in 58.5 sec
#  [-----------------80%----------        ] 80168 of 100000 complete in 59.0 sec
#  [-----------------80%----------        ] 80855 of 100000 complete in 59.5 sec
#  [-----------------81%----------        ] 81530 of 100000 complete in 60.0 sec
#  [-----------------82%-----------       ] 82208 of 100000 complete in 60.5 sec
#  [-----------------82%-----------       ] 82900 of 100000 complete in 61.1 sec
#  [-----------------83%-----------       ] 83558 of 100000 complete in 61.6 sec
#  [-----------------84%------------      ] 84246 of 100000 complete in 62.1 sec
#  [-----------------84%------------      ] 84906 of 100000 complete in 62.6 sec
#  [-----------------85%------------      ] 85564 of 100000 complete in 63.1 sec
#  [-----------------86%------------      ] 86249 of 100000 complete in 63.6 sec
#  [-----------------86%-------------     ] 86911 of 100000 complete in 64.1 sec
#  [-----------------87%-------------     ] 87560 of 100000 complete in 64.6 sec
#  [-----------------88%-------------     ] 88246 of 100000 complete in 65.1 sec
#  [-----------------88%-------------     ] 88920 of 100000 complete in 65.6 sec
#  [-----------------89%--------------    ] 89599 of 100000 complete in 66.1 sec
#  [-----------------90%--------------    ] 90265 of 100000 complete in 66.6 sec
#  [-----------------90%--------------    ] 90913 of 100000 complete in 67.1 sec
#  [-----------------91%--------------    ] 91599 of 100000 complete in 67.6 sec
#  [-----------------92%---------------   ] 92266 of 100000 complete in 68.1 sec
#  [-----------------92%---------------   ] 92931 of 100000 complete in 68.6 sec
#  [-----------------93%---------------   ] 93607 of 100000 complete in 69.1 sec
#  [-----------------94%---------------   ] 94276 of 100000 complete in 69.6 sec
#  [-----------------94%----------------  ] 94969 of 100000 complete in 70.1 sec
#  [-----------------95%----------------  ] 95646 of 100000 complete in 70.6 sec
#  [-----------------96%----------------  ] 96325 of 100000 complete in 71.1 sec
#  [-----------------96%----------------  ] 96941 of 100000 complete in 71.6 sec
#  [-----------------97%----------------- ] 97604 of 100000 complete in 72.1 sec
#  [-----------------98%----------------- ] 98257 of 100000 complete in 72.6 sec
#  [-----------------98%----------------- ] 98899 of 100000 complete in 73.1 sec
#  [-----------------99%----------------- ] 99580 of 100000 complete in 73.6 sec
#  [-----------------100%-----------------] 100000 of 100000 complete in 73.9 sec
# Plotting beta
# Plotting
#  alpha
# Plotting
#  prec

# %%
figsize(12.5, 6)
from scipy.optimize import fmin


def stock_loss(price, pred, coef=500):
    """vectorized for numpy"""
    sol = np.zeros_like(price)
    ix = price * pred < 0
    sol[ix] = coef * pred ** 2 - np.sign(price[ix]) * pred + abs(price[ix])
    sol[~ix] = abs(price[~ix] - pred)
    return sol

tau_samples = mcmc.trace("prec")[:]
alpha_samples = mcmc.trace("alpha")[:]
beta_samples = mcmc.trace("beta")[:]

N = tau_samples.shape[0]

noise = 1. / np.sqrt(tau_samples) * np.random.randn(N)

possible_outcomes = lambda signal: alpha_samples + beta_samples * signal \
    + noise


opt_predictions = np.zeros(50)
trading_signals = np.linspace(X.min(), X.max(), 50)
for i, _signal in enumerate(trading_signals):
    _possible_outcomes = possible_outcomes(_signal)
    tomin = lambda pred: stock_loss(_possible_outcomes, pred).mean()
    opt_predictions[i] = fmin(tomin, 0, disp=False)


plt.xlabel("trading signal")
plt.ylabel("prediction")
plt.title("Least-squares prediction vs. Bayes action prediction")
plt.plot(X, ls_coef_ * X + ls_intercept, label="Least-squares prediction")
plt.xlim(X.min(), X.max())
plt.plot(trading_signals, opt_predictions, label="Bayes action prediction")
plt.legend(loc="upper left");
